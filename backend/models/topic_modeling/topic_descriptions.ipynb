# %%
import sys
sys.path.append('/Users/pablojerezarnau/git/RS-backend/')

import json
from config.settings import TOPIC_MODELING_RUNS_DIR
import os
from collections import OrderedDict

def generate_topic_tokens_dict(file_path):
    """
    Generate a dictionary with topic_id as keys and list of tokens as values,
    sorted by topic_id.

    :param file_path: Path to the topics.json file.
    :return: Dictionary with topic_id as keys and list of tokens as values, sorted by topic_id.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        topics_data = json.load(file)

    topic_tokens_dict = {}
    for topic in topics_data:
        # Flatten the list of token dictionaries into a single list of token names
        tokens_list = [token for tokens_dict in topic['tokens'] for token, score in tokens_dict.items()]
        topic_tokens_dict[topic['topic_number']] = tokens_list

    # Sort the dictionary by topic_number and return an OrderedDict
    sorted_topic_tokens_dict = OrderedDict(sorted(topic_tokens_dict.items()))

    return sorted_topic_tokens_dict

# %%
# Example usage
run_id = '20240319_153921_dataset3_topics_300'
run_dir = os.path.join(TOPIC_MODELING_RUNS_DIR, run_id)
file_path = os.path.join(run_dir, 'topics.json')

topic_tokens_dict = generate_topic_tokens_dict(file_path)

# Print the sorted dictionary
for topic_id, tokens in topic_tokens_dict.items():
    print(f"Topic {topic_id}: {tokens}")
# Out:
# Topic 0: ['girl', 'female', 'swimming', 'russian', 'diving', 'boy', 'stretch', 'dress', 'pool', 'woman']
# Topic 1: ['fail', 'funny', 'compilation', 'instant', 'stupid', 'well', 'epic', 'afv', 'funniest', 'zelda']
# Topic 2: ['technology', 'tech', 'blockchain', 'gadget', 'future', 'late', 'computer', 'innovation', 'technical', 'internet']
# Topic 3: ['asmr', 'cooking', 'satisfy', 'sound', 'eat', 'mukbang', 'camping', 'relax', 'cook', 'sleep']
# Topic 4: ['energy', 'renewable', 'power', 'solar', 'wind', 'country', 'source', 'green', 'clean', 'sustainable']
# Topic 5: ['get', 'talent', 'surfer', 'wave', 'agt', 'america', 'watch', 'subway', 'barrel', 'audition']
# Topic 6: ['furniture', 'smart', 'save', 'space', 'bedroom', 'door', 'karachi', 'small', 'market', 'idea']
# Topic 7: ['interior', 'design', 'house', 'room', 'bedroom', 'home', 'modern', 'decor', 'living', 'designer']
# Topic 8: ['real', 'estate', 'wholesale', 'not', 'feel', 'ghost', 'free', 'invest', 'property', 'deal']
# Topic 9: ['gym', 'fitness', 'near', 'class', 'fit', 'membership', 'club', 'anytime', 'box', 'health']
# Topic 11: ['digital', 'nomad', 'course', 'service', 'work', 'agency', 'ad', 'platform', 'remote', 'search']
# Topic 12: ['baby', 'photoshoot', 'month', 'cute', 'laugh', 'cooking', 'kid', 'cook', 'sculpture', 'shark']
# Topic 13: ['nifty', 'prediction', 'tomorrow', 'bank', 'analysis', 'banknifty', 'october', 'november', 'fifa', 'strategy']
# Topic 14: ['cycle', 'stunt', 'mountain', 'wheelie', 'mtb', 'santa', 'cruz', 'orbea', 'scott', 'bicycle']
# Topic 15: ['success', 'career', 'mindset', 'work', 'job', 'strategy', 'entrepreneur', 'growth', 'advice', 'wellness']
# Topic 16: ['cut', 'coconut', 'fruit', 'healthy', 'cutting', 'smoothie', 'benefit', 'wellness', 'blox', 'juice']
# Topic 17: ['travel', 'guide', 'destination', 'beach', 'budget', 'adventure', 'solo', 'trip', 'safety', 'tour']
# Topic 18: ['blender', 'animation', 'tutorial', 'chatgpt', 'geometry', 'create', '3d', 'robot', 'loop', 'nodes']
# Topic 19: ['let', 'share', 'watch', 'मछल', 'fishing', 'comment', 'know', 'technique', 'thank', 'not']
# Topic 20: ['moment', 'women', 'funny', 'crazy', 'funniest', 'woman', 'wtf', 'diving', 'football', 'athletic']
# Topic 21: ['world', 'exam', 'fast', 'tough', 'conservation', 'war', 'country', 'environment', 'jurassic', 'open']
# Topic 22: ['hack', 'hacking', 'ethical', 'phone', 'life', 'lifehack', 'minute', 'wifi', 'simple', 'trick']
# Topic 23: ['candle', 'make', 'wax', 'soy', 'diy', 'making', 'home', 'beginner', 'style', 'idea']
# Topic 24: ['adventure', 'bungee', 'jump', 'mountain', 'beauty', 'landscape', 'fantasy', 'jumping', 'kayak', 'earth']
# Topic 25: ['grow', 'grape', 'seed', 'gardening', 'garden', 'chilli', 'cutting', 'banana', 'orange', 'guava']
# Topic 26: ['gadget', 'smart', 'appliance', 'home', 'cool', 'kitchen', 'amazon', 'tool', 'utensil', 'invention']
# Topic 27: ['onion', 'pakoda', 'beer', 'lemon', 'phone', 'recipe', 'charger', 'rice', 'style', 'open']
# Topic 28: ['exercise', 'fat', 'elephant', 'belly', 'cid', 'episode', 'drama', 'reduce', 'bl', 'amazon']
# Topic 29: ['fishing', 'catch', 'sea', 'amazing', 'boat', 'मछल', 'bass', 'technique', 'big', 'rod']
# Topic 30: ['experiment', 'science', 'home', 'pressure', 'amazing', 'easy', 'air', 'law', 'school', 'crazy']
# Topic 31: ['woolen', 'flower', 'wool', 'design', 'kadhai', 'craft', 'kaise', 'easy', 'step', 'embroidery']
# Topic 32: ['stock', 'today', 'market', 'share', 'nasdaq', 'dow', 'future', 'buy', 'index', 'chart']
# Topic 33: ['balloon', 'decoration', 'birthday', 'event', 'ganpati', 'tape', 'nano', 'mom', 'foil', 'world']
# Topic 34: ['naruto', 'anime', 'vs', 'amv', 'sasuke', 'parody', 'fight', 'kiss', 'sakura', 'moment']
# Topic 35: ['beginner', 'javascript', 'html', 'course', 'java', 'hindi', 'work', 'invest', 'basic', 'trading']
# Topic 36: ['big', 'tiktok', 'bank', 'challenge', 'pretty', 'waist', 'small', 'bang', 'face', 'tik']
# Topic 37: ['film', 'हनद', 'hindiurdu', 'summarize', 'explain', 'turn', 'wrong', 'horror', 'dead', 'indie']
# Topic 38: ['hairstyle', 'hair', 'long', 'simple', 'korean', 'easy', 'bun', 'style', 'girl', 'school']
# Topic 39: ['social', 'medium', 'content', 'platform', 'post', 'facebook', 'manager', 'marketing', 'influencer', 'socialmedia']
# Topic 40: ['music', 'hit', 'relax', 'pop', 'sleep', 'radio', 'playlist', 'production', 'sound', 'relaxation']
# Topic 41: ['tutorial', 'programming', 'beginner', 'pattern', 'figma', 'step', 'excel', 'learn', 'guide', 'bead']
# Topic 42: ['podcast', 'luke', 'belmar', 'fresh', 'fit', 'clip', 'episode', 'interview', 'ranveer', 'rogan']
# Topic 43: ['kick', 'tutorial', 'tornado', 'taekwondo', 'jump', 'martial', 'drill', 'knockout', 'bungee', 'technique']
# Topic 44: ['day', 'post', 'world', 'national', 'women', 'independence', 'environment', 'conservation', 'poster', 'happy']
# Topic 45: ['diy', 'decor', 'wall', 'handmade', 'stick', 'cream', 'slime', 'ice', 'project', 'christmas']
# Topic 46: ['awareness', 'create', 'raise', 'cctv', 'self', 'camera', 'public', 'job', 'mental', 'social']
# Topic 47: ['make', 'jewelry', 'jewellery', 'gold', 'ganesh', 'bracelet', 'bead', 'murti', 'earring', 'handmade']
# Topic 48: ['garden', 'gardening', 'beer', 'vegetable', 'bottle', 'tool', 'beginner', 'passion', 'organic', 'hack']
# Topic 49: ['photo', 'edit', 'editing', 'photoshoot', 'shoot', 'picsart', 'lightroom', 'background', 'pose', 'picture']
# Topic 50: ['reel', 'tweet', 'fake', 'bt', 'assamese', 'time', 'reels', 'punjabi', 'motion', 'alight']
# Topic 51: ['animation', 'effect', 'animate', 'vfx', 'film', 'amanda', 'create', 'sonic', 'huggy', 'wuggy']
# Topic 52: ['skibidi', 'toilet', 'tv', 'watch', 'lego', 'yes', 'titan', 'episode', 'man', 'cameraman']
# Topic 53: ['robot', 'link', 'advantage', 'read', 'article', 'disadvantage', 'robotic', 'emo', 'feature', 'use']
# Topic 54: ['tractor', 'bhoot', 'ki', 'wala', 'modify', 'shower', 'jcb', 'mini', 'trolley', 'farming']
# Topic 55: ['skill', 'welding', 'freelance', 'woodworke', 'weld', 'woodworking', 'fabrication', 'job', 'goal', 'freelancing']
# Topic 56: ['haul', 'meesho', 'kurti', 'set', 'kurta', 'amazon', 'flipkart', 'top', 'chikankari', 'dress']
# Topic 57: ['urdu', 'calligraphy', 'arabic', 'pen', 'lettering', 'brush', 'letter', 'islamic', 'allah', 'pakistan']
# Topic 58: ['bike', 'sports', 'lakh', 'mountain', 'ktm', 'yamaha', 'ninja', 'drive', 'kawasaki', 'rider']
# Topic 59: ['quran', 'translation', 'surah', 'urdu', 'recitation', 'tilawat', 'beautiful', 'holy', 'tarjuma', 'yaseen']
# Topic 60: ['electric', 'vehicle', 'ev', 'shortvideo', 'beautiful', 'tesla', 'diving', 'electrical', 'mahindra', 'battery']
# Topic 61: ['motivation', 'billionaire', 'bodybuilde', 'luxury', 'inspiration', 'mindset', 'fitness', 'view', 'sigma', 'miranda']
# Topic 62: ['beat', 'type', 'fl', 'studio', 'rage', 'free', 'sad', 'lil', 'jazz', 'trap']
# Topic 63: ['prank', 'public', 'funny', 'reaction', 'wife', 'anatoly', 'prankprank', 'pranksprank', 'ghost', 'classy']
# Topic 64: ['bgmi', 'pubg', 'mobile', 'update', 'gameplay', 'news', 'test', 'download', 'unban', 'jonathan']
# Topic 65: ['idea', 'decoration', 'decor', 'wall', 'gift', 'photoshoot', 'card', 'ganpati', 'diwali', 'birthday']
# Topic 66: ['free', 'fire', 'yutubeshort', 'totalgame', 'dj', 'alok', 'freefiremax', 'videofree', 'bhai', 'event']
# Topic 67: ['khan', 'shahrukh', 'jawan', 'shah', 'rukh', 'trailer', 'hand', 'leo', 'late', 'pathan']
# Topic 68: ['turtle', 'python', 'graphic', 'code', 'amazing', 'graphics', 'animation', 'design', 'module', 'speed']
# Topic 69: ['sofa', 'bed', 'furniture', 'chair', 'set', 'price', 'cheap', 'table', 'market', 'home']
# Topic 70: ['comedy', 'stand', 'standup', 'comedian', 'film', 'joke', 'skit', 'matt', 'rife', 'humour']
# Topic 71: ['hair', 'clip', 'style', 'clipper', 'growth', 'kaise', 'make', 'sound', 'transplant', 'banana']
# Topic 72: ['draw', 'step', 'easy', 'pencil', 'drawing', 'beautiful', 'pastel', 'scenery', 'oil', 'krishna']
# Topic 73: ['bird', 'sound', 'watch', 'sleep', 'feeder', 'forest', 'hunt', 'relax', 'soothe', 'beautiful']
# Topic 74: ['chess', 'trap', 'trick', 'opening', 'win', 'white', 'move', 'beginner', 'black', 'open']
# Topic 75: ['pattern', 'chart', 'analysis', 'candlestick', 'action', 'price', 'technical', 'stick', 'forex', 'pdf']
# Topic 76: ['kaise', 'software', 'engineer', 'bane', 'view', 'kare', 'badhaye', 'increase', 'ke', 'se']
# Topic 77: ['tiktok', 'compilation', 'twerk', 'mashup', 'nevada', 'boom', 'follow', 'challenge', 'xo', 'bigbang']
# Topic 78: ['piano', 'john', 'runaway', 'cena', 'theme', 'note', 'easy', 'sheet', 'aurora', 'music']
# Topic 79: ['finance', 'financial', 'invest', 'personal', 'investment', 'crypto', 'management', 'advice', 'wealth', 'cryptocurrency']
# Topic 80: ['status', 'whatsapp', 'screen', 'kiss', 'cute', '4k', 'romantic', 'sad', 'august', 'song']
# Topic 81: ['shayari', 'urdu', 'sad', 'शयर', 'love', 'shayri', 'heart', 'line', 'pakistan', 'ghazal']
# Topic 82: ['physics', 'class', 'chemistry', 'mechanic', 'quantum', 'wallah', 'force', 'sir', 'law', 'newton']
# Topic 83: ['game', 'wow', 'time', 'android', 'unity', 'culture', 'development', 'gameplay', 'games', 'action']
# Topic 84: ['piano', 'tutorial', 'easy', 'play', 'past', 'go', 'cover', 'music', 'instrumental', 'sheet']
# Topic 85: ['paint', 'painting', 'acrylic', 'technique', 'beginner', 'easy', 'abstract', 'art', 'canvas', 'brush']
# Topic 86: ['css', 'html', 'animation', 'javascript', 'text', 'center', 'effect', 'code', 'button', 'tutorial']
# Topic 87: ['code', 'programming', 'drive', 'cheat', 'program', 'computer', 'software', 'javascript', 'developer', 'boost']
# Topic 88: ['flower', 'arrangement', 'woolen', 'beautiful', 'easy', 'bouquet', 'wool', 'paper', 'idea', 'vase']
# Topic 89: ['crypto', 'bitcoin', 'price', 'cryptocurrency', 'coin', 'btc', 'news', 'altcoin', 'prediction', 'trading']
# Topic 90: ['time', 'school', 'wow', 'tumakuru', 'snowboard', 'heart', 'education', 'student', 'sacred', '9dvr']
# Topic 91: ['health', 'mental', 'fitness', 'wellness', 'anxiety', 'healthy', 'depression', 'improve', 'wellbeing', 'stress']
# Topic 92: ['easy', 'rangoli', 'thai', 'origami', 'kolam', 'simple', 'wall', 'beginner', 'useful', 'bead']
# Topic 93: ['numerology', 'number', 'astrology', 'chinese', 'excel', 'guy', 'gary', 'zodiac', 'mean', 'sign']
# Topic 94: ['learn', 'machine', 'learning', 'course', 'datum', 'interview', 'knowledge', 'deep', 'education', 'intelligence']
# Topic 95: ['pig', 'peppa', 'kid', 'watch', 'little', 'episode', 'kids', 'official', 'friend', 'play']
# Topic 96: ['bottle', 'plastic', 'snowboard', 'diamond', 'rescue', 'waste', 'recycle', 'sustainable', 'jewelry', 'break']
# Topic 97: ['event', 'management', 'company', 'wedding', 'kerala', 'corporate', 'planner', 'kochi', 'conference', 'india']
# Topic 98: ['cheese', 'pizza', 'sandwich', 'ethical', 'mozzarella', 'grill', 'paratha', 'homemade', 'tool', 'textile']
# Topic 99: ['language', 'programming', 'beginner', 'program', 'thai', 'learn', 'basic', 'loop', 'array', 'course']
# Topic 100: ['trading', 'strategy', 'trade', 'indicator', 'forex', 'tradingview', 'option', 'binance', 'crypto', 'intraday']
# Topic 101: ['indian', 'drive', 'south', 'cheat', 'king', 'update', 'india', 'diwali', 'dinosaur', 'army']
# Topic 102: ['egg', 'eat', 'challenge', 'boil', 'chinese', 'half', 'dish', 'benefit', 'fry', 'chicken']
# Topic 103: ['review', 'public', 'adipurush', 'opinion', 'reaction', 'unbox', 'fdf', 'talk', 'restaurant', 'product']
# Topic 104: ['gaming', 'highlight', 'clip', 'pc', 'moment', 'game', 'payal', 'content', 'community', 'intense']
# Topic 105: ['diwali', 'dress', 'miniature', 'barbie', 'experiment', 'mini', 'doll', 'cracker', 'kid', 'sky']
# Topic 106: ['dj', 'wala', 'lal', 'setup', 'khesari', 'gadi', 'remix', 'gana', 'mix', 'job']
# Topic 107: ['engine', 'old', 'black', 'start', 'diesel', 'ruston', 'oil', 'sound', 'hornsby', 'village']
# Topic 108: ['makeup', 'beauty', 'lipstick', 'look', 'sugar', 'eye', 'lip', 'halloween', 'korean', 'blackpink']
# Topic 109: ['study', 'class', 'aesthetic', 'student', 'exam', 'motivation', 'school', 'kdrama', 'minimalism', 'education']
# Topic 110: ['explain', 'movie', 'zombie', 'hollywood', 'horror', 'explanation', 'hindiurdu', 'voice', 'हनद', 'summarize']
# Topic 111: ['embroidery', 'machine', 'jean', 'stitch', 'embroider', 'hoop', 'design', 'work', 'jeans', 'sewing']
# Topic 112: ['sport', 'sports', 'lakh', 'yamaha', 'bike', 'price', 'extreme', 'diving', 'pakistan', 'athlete']
# Topic 113: ['tok', 'tik', 'tiktok', 'couple', 'compilation', 'jewelry', 'song', 'house', 'hype', 'dance']
# Topic 114: ['training', 'course', 'puppy', 'train', 'trainer', 'link', 'k9', 'canine', 'equipment', 'standard']
# Topic 115: ['ariana', 'grande', 'vocal', 'live', 'high', 'human', 'note', 'music', 'not', 'song']
# Topic 116: ['design', 'mehndi', 'rangoli', 'simple', 'henna', 'mehandi', 'hand', 'arabic', 'kolam', 'special']
# Topic 117: ['tattoo', 'pen', 'share', 'ink', 'design', 'home', 'mehandi', 'mom', 'easy', 'beginner']
# Topic 118: ['meme', 'funny', 'laugh', 'find', 'discord', 'memes', 'compilation', 'gacha', 'dank', 'clean']
# Topic 119: ['chess', 'checkmate', 'puzzle', 'tactic', 'opening', 'strategy', 'play', 'gothamchess', 'move', 'game']
# Topic 120: ['samsung', 'galaxy', 'lock', 'screen', 'notification', 'test', 'watch', 'price', 'camera', 'unbox']
# Topic 121: ['book', 'read', 'recommendation', 'romance', 'booktube', 'booktok', 'classic', 'fiction', 'comic', 'fantasy']
# Topic 122: ['hindi', 'movie', 'dub', 'south', 'hollywood', 'filmy', 'moviereview', 'shorts', 'biography', 'ki']
# Topic 123: ['pose', 'boy', 'miss', 'photoshoot', 'stand', 'stylish', 'sunglass', 'couple', 'attitude', 'walking']
# Topic 124: ['mobile', 'phone', 'smartphone', 'android', 'fifa', 'pubg', 'invest', 'cover', 'trick', 'emergency']
# Topic 125: ['paneer', 'ki', 'recipe', 'sabji', 'kaise', 'masala', 'hai', 'banane', 'ka', 'banta']
# Topic 126: ['hacker', 'ethical', 'attitude', 'hacking', 'hack', 'career', 'status', 'programming', 'diwali', 'hat']
# Topic 127: ['truck', 'driver', 'practice', 'canada', 'speaking', 'app', 'tractor', 'earn', 'monster', 'salary']
# Topic 128: ['jupiter', 'moon', 'earth', 'near', 'planet', 'telescope', 'venus', 'close', 'today', 'gb']
# Topic 129: ['craft', 'paper', 'idea', 'minute', 'easy', 'diy', 'bottle', 'kid', 'plastic', '5minute']
# Topic 130: ['attitude', 'status', 'billionaire', 'sigma', 'rule', 'boy', 'marvel', 'peaky', 'blinder', 'spiderman']
# Topic 131: ['motivational', 'speech', 'motivation', 'peterson', 'jordan', 'inspirational', 'success', 'rule', 'hindi', 'sigma']
# Topic 132: ['tamil', 'voice', 'mr', 'dub', 'hollywood', 'mystery', 'explanation', 'minute', 'roman', 'reign']
# Topic 133: ['movie', 'film', 'recap', 'south', 'trailer', 'horror', 'scene', 'fi', 'sci', 'fantasy']
# Topic 134: ['luxury', 'dubai', 'prince', 'billionaire', 'hamdan', 'fazza', 'bin', 'chandrayaan', 'sheikh', 'experience']
# Topic 135: ['fashion', 'style', 'outfit', 'dress', 'men', 'beautiful', 'look', 'beauty', 'model', 'designer']
# Topic 136: ['india', 'sportbike', 'bike', 'lakh', 'price', 'super', 'canyon', 'sport', 'ktm', 'unknown']
# Topic 137: ['dance', 'pakistani', 'performance', 'calm', 'wedding', 'mom', 'dancer', 'kpop', 'perform', 'choreography']
# Topic 138: ['roblox', 'friend', 'rainbow', 'door', 'free', 'simulator', 'job', 'bedwar', 'maldive', 'pet']
# Topic 139: ['thriller', 'michael', 'jackson', 'suspense', 'mystery', 'series', 'watch', 'netflix', 'korean', 'crime']
# Topic 140: ['write', 'writing', 'english', 'letter', 'storytelle', 'style', 'class', 'handwriting', 'practice', 'job']
# Topic 141: ['content', 'help', 'tool', 'website', 'link', 'follow', 'people', 'service', 'create', 'provide']
# Topic 142: ['market', 'prediction', 'price', 'today', 'coin', 'share', 'nifty', 'cro', 'cryptocom', 'pepe']
# Topic 143: ['bow', 'compound', 'ball', 'steel', 'archery', 'hunt', 'beginner', 'amazon', 'shoot', 'compoundbow']
# Topic 144: ['love', 'letter', 'go', 'tarot', 'romantic', 'relationship', 'girlfriend', 'boyfriend', 'pisce', 'couple']
# Topic 145: ['ring', 'engagement', 'diamond', 'lab', 'grow', 'unique', 'shopping', 'affordable', 'sustainable', 'woman']
# Topic 146: ['note', 'death', 'redmi', 'plus', 'character', 'japanese', 'cast', 'end', 'episode', 'anime']
# Topic 147: ['live', 'today', 'nifty', 'past', 'dow', 'future', 'index', 'share', 'price', 'nasdaq']
# Topic 148: ['piece', 'piano', 'sheet', 'music', 'anime', 'luffy', 'be', 'op', 'we', 'open']
# Topic 149: ['moon', 'today', 'planet', 'venus', 'star', 'pisce', 'march', 'tarot', '2023eid', 'view']
# Topic 150: ['psychology', 'human', 'right', 'mental', 'behavior', 'peterson', 'fact', 'jordan', 'mind', 'crush']
# Topic 151: ['reddit', 'askreddit', 'post', 'reaction', 'bake', 'laugh', 'redditshort', 'confession', 'delight', 'redditstorie']
# Topic 152: ['online', 'shopping', 'earn', 'training', 'income', 'work', 'website', 'job', 'freelance', 'class']
# Topic 153: ['drone', 'dji', 'camera', 'mini', 'fly', 'mavic', 'aerial', 'shoot', 'footage', '4k']
# Topic 154: ['water', 'filter', 'kayak', 'candle', 'maldive', 'sanitizer', 'float', 'nerf', 'save', 'conservation']
# Topic 155: ['workout', 'exercise', 'fitness', 'gym', 'body', 'abs', 'ab', 'pack', 'muscle', 'bicep']
# Topic 156: ['apple', 'device', 'watch', 'pro', 'app', 'accessory', 'feature', 'vision', 'ipad', 'iphone']
# Topic 157: ['ux', 'ui', 'design', 'figma', 'designer', 'user', 'uiux', 'app', 'experience', 'course']
# Topic 158: ['horror', 'scary', 'ghost', 'bhoot', 'paranormal', 'story', 'true', 'animate', 'haunt', 'real']
# Topic 159: ['piano', 'believer', 'hurt', 'dragon', 'gun', 'sheet', 'radioactive', 'change', 'chord', 'imagine']
# Topic 160: ['free', 'fire', 'freefire', 'ff', 'event', 'garena', 'emote', 'diamond', 'download', 'max']
# Topic 161: ['coffee', 'brew', 'bean', 'espresso', 'black', 'drink', 'brewing', 'roast', 'milk', 'cappuccino']
# Topic 162: ['web', 'development', 'html', 'developer', 'website', 'stack', 'learn', 'javascript', 'software', 'frontend']
# Topic 163: ['reality', 'virtual', 'augment', 'ar', 'vr', 'experience', 'realistic', 'technology', 'education', 'educational']
# Topic 164: ['tree', 'lemon', 'guava', 'climb', 'google', 'grape', 'graft', 'machine', 'grafting', 'climber']
# Topic 165: ['art', 'nail', 'artist', 'martial', 'beautiful', 'fight', 'sculpture', 'silo', 'artwork', 'fu']
# Topic 166: ['cartoon', 'bhoot', 'wala', 'kid', 'screen', 'green', 'poor', 'kahani', 'bhutiya', 'help']
# Topic 167: ['weight', 'loss', 'fat', 'lose', 'belly', 'camping', 'exercise', 'diet', 'cooking', 'plan']
# Topic 168: ['market', 'stock', 'trading', 'share', 'trade', 'intraday', 'option', 'today', 'analysis', 'live']
# Topic 169: ['sad', 'reality', 'world', 'deep', 'picture', 'modern', 'meaning', 'today', 'heart', 'break']
# Topic 170: ['solar', 'system', 'planet', 'panel', 'view', 'badhaye', 'power', 'sun', 'cleaning', 'astronomy']
# Topic 171: ['neet', 'aiims', 'motivation', 'mbbs', 'delhi', 'aiim', 'student', 'iiit', 'college', 'medical']
# Topic 172: ['security', 'cyber', 'cybersecurity', 'career', 'course', 'job', 'datum', 'certification', 'ethical', 'program']
# Topic 173: ['monkey', 'primate', 'jungle', 'conservation', 'baby', 'wildlife', 'pet', 'adorable', 'adventure', 'heartwarming']
# Topic 174: ['nikon', 'camera', 'photoshoot', 'z8', 'd5600', 'photography', 'mm', 'dslr', 'lens', 'd3500']
# Topic 175: ['blouse', 'neck', 'quilt', 'gift', 'sewing', 'bag', 'box', 'sew', 'quilting', 'leo']
# Topic 176: ['seo', 'keyword', 'search', 'optimization', 'rank', 'strategy', 'tool', 'website', 'google', 'chatgpt']
# Topic 177: ['vs', 'cane', 'corso', 'chemistry', 'yin', 'lan', 'xrp', 'ice', 'leo', 'hulk']
# Topic 178: ['photography', 'mobile', 'idea', 'trick', 'photoshoot', 'photo', 'phone', 'beginner', 'shoot', 'pose']
# Topic 179: ['face', 'mask', 'watch', 'ryan', 'satisfy', 'machine', 'dr', 'effect', 'skincare', 'ayurveda']
# Topic 180: ['python', 'programming', 'beginner', 'code', 'question', 'datum', 'learn', 'function', 'course', 'program']
# Topic 181: ['dog', 'cane', 'corso', 'training', 'puppy', 'train', 'trainer', 'rescue', 'canine', 'pitbull']
# Topic 182: ['glass', 'blow', 'shortvideo', 'bottle', 'break', 'viralshort', 'satisfy', 'shortsfeed', 'ytshort', 'stair']
# Topic 183: ['pet', 'cat', 'cute', 'insurance', 'simulator', 'dog', 'kitten', 'care', 'near', 'huge']
# Topic 184: ['king', 'play', 'ludo', 'ladder', 'game', 'board', 'player', 'friend', 'match', 'lion']
# Topic 185: ['fortnite', 'setting', 'ps5', 'season', 'chapter', 'pc', 'settings', 'update', 'battle', 'map']
# Topic 186: ['fnaf', 'plushie', 'figure', 'action', 'night', 'freddys', 'costume', 'trailer', 'kid', 'funko']
# Topic 187: ['superhero', 'marvel', 'super', 'gadget', 'hero', 'spiderman', 'amazon', 'superheroes', 'dc', 'female']
# Topic 188: ['cursive', 'handwriting', 'letter', 'calligraphy', 'practice', 'english', 'beautiful', 'abcd', 'handwrite', 'beginner']
# Topic 189: ['thai', 'journey', 'lesson', 'not', 'join', 'culture', 'stay', 'insight', 'learn', 'provide']
# Topic 190: ['respect', 'respectful', 'moment', 'ringtone', 'bean', 'mr', 'amazing', 'independence', 'boss', 'woman']
# Topic 191: ['pose', 'photoshoot', 'fashion', 'style', 'saree', 'stylish', 'man', 'model', 'selfie', 'men']
# Topic 192: ['marketing', 'digital', 'strategy', 'agency', 'course', 'advertising', 'online', 'company', 'medium', 'affiliate']
# Topic 193: ['plant', 'garden', 'indoor', 'house', 'care', 'grow', 'gardening', 'vegetable', 'propagation', 'vine']
# Topic 194: ['change', 'climate', 'environmental', 'impact', 'global', 'sustainable', 'environment', 'future', 'action', 'people']
# Topic 195: ['story', 'animate', 'true', 'scary', 'storytelle', 'moral', 'dogman', 'reddit', 'paranormal', 'tale']
# Topic 196: ['rap', 'beat', 'instrumental', 'boom', 'de', 'hop', 'hip', 'libre', 'free', 'freestyle']
# Topic 197: ['vr', 'virtual', 'funny', 'fail', 'quest', 'reality', 'game', 'velankanni', 'moment', 'reaction']
# Topic 198: ['car', 'drift', 'rc', 'stunt', 'beamng', 'drive', 'super', 'speed', 'thar', 'gadi']
# Topic 199: ['saree', 'dress', 'shopping', 'price', 'wear', 'collection', 'party', 'late', 'blouse', 'shop']
# Topic 200: ['tag', 'gorilla', 'vr', 'gorillatag', 'update', 'oculus', 'quest', 'gtag', 'play', 'game']
# Topic 201: ['land', 'cruiser', 'toyota', 'review', 'series', 'chandrayaan', 'suv', 'car', 'offroad', 'rover']
# Topic 202: ['kitchen', 'amazon', 'pvc', 'gadget', 'appliance', 'cooking', 'minimalism', 'modular', 'invention', 'utensil']
# Topic 203: ['funny', 'china', 'laugh', 'moment', 'cat', 'comedy', 'try', 'cute', 'fun', 'reaction']
# Topic 204: ['fragrance', 'perfume', 'gift', 'cologne', 'bear', 'compliment', 'scent', 'summer', 'set', 'men']
# Topic 205: ['resort', 'bangalore', 'near', 'place', 'stay', 'adventure', 'day', 'bengaluru', 'luxury', 'outing']
# Topic 206: ['ultra', 's23', 'samsung', 'bl', 'galaxy', 'smartwatch', 'unbox', 'series', 'camera', 'drama']
# Topic 207: ['fast', 'black', 'background', 'template', 'effect', 'screen', 'lose', 'weight', 'light', 'run']
# Topic 208: ['surf', 'wave', 'surfer', 'pro', 'surfing', 'big', 'lacanau', 'wsl', 'ocean', 'turn']
# Topic 209: ['meditation', 'affirmation', 'positive', 'guide', 'mindfulness', 'sleep', 'relax', 'morning', 'help', 'law']
# Topic 210: ['challenge', 'fitness', 'eat', 'fun', 'try', 'laugh', 'hard', 'emoji', 'spicy', 'accept']
# Topic 211: ['animal', 'rescue', 'mythology', 'specie', 'endanger', 'cute', 'dog', 'fantasy', 'species', 'wild']
# Topic 212: ['science', 'class', 'fiction', 'model', 'ke', 'magic', 'amazing', 'student', 'biography', 'filmy']
# Topic 213: ['business', 'start', 'strategy', 'small', 'entrepreneur', 'ecommerce', 'service', 'entrepreneurship', 'startup', 'customer']
# Topic 214: ['ai', 'intelligence', 'artificial', 'tool', 'chatgpt', 'google', 'future', 'artificialintelligence', 'datum', 'human']
# Topic 215: ['chennai', 'street', 'tamil', 'biryani', 'tamilvlog', 'chicken', 'veg', 'review', 'peppa', 'peppafoodie']
# Topic 216: ['forensic', 'crime', 'analysis', 'scene', 'exam', 'investigation', 'police', 'true', 'knowledge', 'fight']
# Topic 217: ['controller', 'sensitivity', 'fortnite', 'setting', 'console', 'ps4', 'xbox', 'target', 'fortnitefortnite', 'edit']
# Topic 218: ['use', 'copyright', 'fair', 'disclaimer', 'purpose', 'act', 'educational', 'section', 'comment', 'research']
# Topic 219: ['tv', 'slam', 'poetry', 'subway', 'surfer', 'word', 'serial', 'sun', 'facebook', 'poetryslam']
# Topic 220: ['logo', 'illustrator', 'design', 'graphic', 'adobe', 'letter', 'coreldraw', 'pixellab', 'signature', 'remove']
# Topic 221: ['poetry', 'urdu', 'poem', 'sad', 'iqbal', 'love', 'line', 'status', 'slam', 'poet']
# Topic 222: ['team', 'build', 'activity', 'building', 'pc', 'thai', 'nevada', 'work', 'group', 'corporate']
# Topic 223: ['design', 'sleeve', 'blouse', 'trouser', 'border', 'late', 'neck', 'page', 'suit', 'cutting']
# Topic 224: ['hollywood', 'movie', 'fiction', 'action', 'scifi', 'dub', 'biography', 'filmy', 'shorts', 'moviereview']
# Topic 225: ['song', 'hit', 'lal', 'khesari', 'pop', 'playlist', 'punjabi', 'radio', 'dj', 'kid']
# Topic 226: ['shoe', 'custom', 'customization', 'sneaker', 'brand', 'unique', 'fashion', 'tennis', 'process', 'collection']
# Topic 227: ['nature', 'sound', 'natural', 'beautiful', 'landscape', 'beauty', 'relaxation', '4k', 'forest', 'serene']
# Topic 228: ['photoshop', 'graphic', 'effect', 'design', 'adobe', 'tutorial', 'background', 'illustrator', 'freelance', 'google']
# Topic 229: ['hike', 'hiking', 'camping', 'ghost', 'style', 'cooking', 'stretch', 'scary', 'paranormal', 'lover']
# Topic 230: ['street', 'famous', 'kolkata', 'style', 'outfit', 'coconut', 'graffiti', 'dahi', 'tour', 'india']
# Topic 231: ['photography', 'camera', 'dslr', 'smoke', 'light', 'canon', 'bomb', 'coolpix', 'sunset', 'beginner']
# Topic 232: ['motor', 'dc', 'project', 'light', 'simple', 'invention', 'lead', 'fan', 'control', 'science']
# Topic 233: ['skin', 'care', 'glow', 'self', 'summer', 'yin', 'acne', 'skincare', 'oily', 'ayurveda']
# Topic 234: ['guy', 'stumble', 'map', 'update', 'world', 'google', 'race', 'record', 'trick', 'height']
# Topic 235: ['draw', 'art', 'drawing', 'sketch', 'graffiti', 'pen', 'cute', 'satisfy', 'easy', 'letter']
# Topic 236: ['vlog', 'mini', 'maldive', 'daily', 'joshi', 'tour', 'college', 'minivlog', 'mbbs', 'sourav']
# Topic 237: ['gk', 'question', 'knowledge', 'general', 'answer', 'tcs', 'marathi', 'class', 'paper', 'exam']
# Topic 238: ['food', 'street', 'foodie', 'cooking', 'preservation', 'additive', 'eat', 'cook', 'cholesterol', 'high']
# Topic 239: ['capcut', 'edit', 'motion', 'alight', 'effect', 'editing', '4k', 'anime', 'transition', 'text']
# Topic 240: ['space', 'save', 'mission', 'exploration', 'nasa', 'universe', 'spacex', 'cosmic', 'launch', 'technology']
# Topic 241: ['fact', 'amazing', 'interesting', 'know', 'female', 'crazy', 'wholesome', 'knowledge', 'mystery', 'fun']
# Topic 242: ['gta', 'techno', 'gamerz', 'episode', 'hulk', 'gamer', 'gameplay', 'game', 'grand', 'gta5']
# Topic 243: ['football', 'freestyle', 'vs', 'soccer', 'juggle', 'messi', 'fifa', 'goal', 'neymar', 'juggling']
# Topic 244: ['wildlife', 'conservation', 'elephant', 'habitat', 'animal', 'species', 'wild', 'natural', 'endanger', 'education']
# Topic 245: ['cricket', 'swing', 'ball', 'se', 'tennis', 'air', 'check', 'vs', 'shot', 'ipl']
# Topic 246: ['hai', 'tanhai', 'dance', 'ye', 'kyu', 'streetdance', 'streetart', 'kyun', 'explore', 'streetstyle']
# Topic 247: ['horse', 'ride', 'race', 'horseback', 'equestrian', 'ghoda', 'racing', 'pet', 'beautiful', 'country']
# Topic 248: ['man', 'hulk', 'iron', 'spiderman', 'avenger', 'spider', 'ki', 'marvel', 'thor', 'wala']
# Topic 249: ['iphone', 'shoot', 'pro', 'max', 'shot', 'xr', 'screen', 'phone', 'case', 'repair']
# Topic 250: ['magnus', 'carlsen', 'chess', 'hikaru', 'kite', 'chess24', 'nakamura', 'watch', 'sigma', 'vs']
# Topic 251: ['history', 'weird', 'ancient', 'historical', 'documentary', 'knowledge', 'roosevelt', 'eleanor', 'war', 'crazy']
# Topic 252: ['pottery', 'clay', 'sculpture', 'sculpt', 'ceramic', 'barn', 'polymer', 'miniature', 'wheel', 'doll']
# Topic 253: ['pokemon', 'shiny', 'ash', 'pokémon', 'card', 'mega', 'charizard', 'rangoli', 'league', 'battle']
# Topic 254: ['fpv', 'drone', 'dji', 'race', 'fly', 'flight', 'simulator', 'valparaiso', 'downhill', 'mtb']
# Topic 255: ['quantum', 'computing', 'computer', 'compute', 'entanglement', 'technology', 'work', 'mechanic', 'explain', 'qubit']
# Topic 256: ['whatsapp', 'status', 'punjabi', 'attitude', 'boy', 'touch', 'roman', 'reign', 'heart', 'love']
# Topic 257: ['life', 'gacha', 'aiims', 'lifehack', 'student', 'mbbs', 'past', 'daily', 'village', 'simple']
# Topic 258: ['money', 'earn', 'finance', 'watch', 'ad', 'adsense', 'astrology', 'job', 'way', 'blogge']
# Topic 259: ['3d', 'print', 'printing', 'printer', 'vfx', 'drive', 'effect', 'cheat', 'model', 'bambu']
# Topic 260: ['wedding', 'pakistani', 'film', 'freelance', 'indie', 'party', 'performance', 'invitation', 'planner', 'bridal']
# Topic 261: ['ronaldo', 'cristiano', 'messi', 'football', 'cr7', 'al', 'nassr', 'goal', 'reaction', 'cup']
# Topic 262: ['skate', 'skating', 'ice', 'figure', 'skater', 'freestyle', 'inline', 'road', 'cream', 'learn']
# Topic 263: ['piano', 'wake', 'music', 'easy', 'sheet', 'runaway', 'chord', 'end', 'september', 'tutorial']
# Topic 264: ['telugu', 'troll', 'ghost', 'poor', 'tech', 'late', 'help', 'people', 'cinema', 'array']
# Topic 265: ['paper', 'origami', 'craft', 'easy', 'airplane', 'gift', 'fold', 'plane', 'star', 'diy']
# Topic 266: ['iit', 'vs', 'jee', 'iiit', 'nit', 'delhi', 'main', 'bombay', 'allahabad', 'hyderabad']
# Topic 267: ['cake', 'chocolate', 'decoration', 'decorate', 'birthday', 'simple', 'biscuit', 'bake', 'unique', 'vanilla']
# Topic 268: ['recipe', 'healthy', 'cook', 'chicken', 'easy', 'cooking', 'food', 'breakfast', 'bake', 'salad']
# Topic 269: ['yoga', 'stretch', 'flexibility', 'morning', 'exercise', 'flow', 'belly', 'reduce', 'body', 'fat']
# Topic 270: ['lego', 'star', 'build', 'set', 'war', 'moc', 'minifigure', 'brick', 'speed', 'city']
# Topic 271: ['content', 'lal', 'khesari', 'strategy', 'singh', 'yadav', 'bhojpuri', 'paranormal', 'indicator', 'camera']
# Topic 272: ['minecraft', 'realistic', 'bear', 'super', 'server', 'culture', 'instal', 'roleplay', 'touch', 'game']
# Topic 273: ['snake', 'lizard', 'io', 'ladder', 'fight', 'big', 'reptile', 'google', 'anaconda', 'cobra']
# Topic 274: ['magic', 'rubber', 'band', 'talent', 'fantasy', 'adventure', 'magician', 'guide', 'engine', 'game']
# Topic 275: ['nail', 'easy', 'nailart', 'polish', 'mehndi', 'gel', 'tool', 'simple', 'arabic', 'french']
# Topic 276: ['rc', 'remote', 'control', 'helicopter', 'toy', 'unbox', 'car', 'gadi', 'boat', 'repair']
# Topic 277: ['photography', 'miniature', 'photographer', 'wildlife', 'landscape', 'wildlifephotography', 'photograph', 'beginner', 'popular', 'shot']
# Topic 278: ['project', 'class', 'work', 'model', 'border', 'working', 'modelscience', 'easyscience', 'dc', 'student']
# Topic 279: ['trick', 'magic', 'band', 'ke', 'rubber', 'amazing', 'card', 'ka', 'science', 'coin']
# Topic 280: ['pro', 'plus', 'realme', 'redmi', 'test', 'camera', 'unbox', 'note', 'price', 'vs']
# Topic 281: ['creative', 'trick', 'photography', 'map', 'knot', 'writing', 'tie', 'protein', 'reactive', 'hear']
# Topic 282: ['family', 'ancestry', 'feud', 'genealogy', 'tree', 'celebrity', 'guy', 'steve', 'kid', 'harvey']
# Topic 283: ['interview', 'upsc', 'question', 'guy', 'ias', 'stumble', 'topper', 'answer', 'sleep', 'job']
# Topic 284: ['xxxtentacion', 'look', 'yung', 'bratz', 'official', 'audio', 'rauf', 'faik', 'lil', 'bad']
# Topic 285: ['joe', 'rogan', 'peterson', 'jordan', 'jre', 'experience', 'fitness', 'chicken', 'joerogan', 'discussion']
# Topic 286: ['fish', 'aquarium', 'fishing', 'pet', 'tank', 'machhali', 'market', 'hunt', 'big', 'cut']
# Topic 287: ['explore', 'shiv', 'हर', 'har', 'sneaker', 'लख', 'streetart', 'join', 'abandon', 'shiva']
# Topic 288: ['brand', 'ad', 'personal', 'strategy', 'influencer', 'facebook', 'customer', 'campaign', 'target', 'branding']
# Topic 289: ['documentary', 'pbs', 'ken', 'history', 'burns', 'burn', 'netflix', 'documentaries', 'watch', 'frontline']
# Topic 290: ['skincare', 'routine', 'skin', 'morning', 'de', 'korean', 'product', 'acne', 'oily', 'beauty']
# Topic 291: ['quote', 'hiccup', 'motivational', 'inspirational', 'documentaries', 'life', 'pbs', 'cause', 'mark', 'twain']
# Topic 292: ['hanuman', 'chalisa', 'ram', 'shree', 'jai', 'ghost', 'song', 'ji', 'snowboard', 'facebook']
# Topic 293: ['home', 'decor', 'construction', 'smart', 'work', 'job', 'photoshoot', 'house', 'month', 'exercise']
# Topic 294: ['app', 'edit', 'earn', 'android', 'editing', 'instal', 'booyah', 'background', 'problem', 'download']
# Topic 295: ['embroidery', 'hand', 'design', 'stitch', 'flower', 'kadhai', 'beginner', 'work', 'easy', 'basic']
# Topic 296: ['yin', 'studio', 'beat', 'fl', 'build', 'couple', 'hero', 'rage', 'production', 'time']
# Topic 297: ['news', 'fox', 'xrp', 'late', 'follow', 'today', 'update', 'ripple', 'break', 'watch']
# Topic 298: ['place', 'visit', 'not', 'feel', 'beautiful', 'earth', 'real', 'travel', 'destination', 'seoul']
# Topic 299: ['sign', 'zodiac', 'tarot', 'leo', 'pisce', 'arie', 'horoscope', 'today', 'capricorn', 'power']

# %%
topic_descriptions = {
    0: "Swimming Diversity",
    1: "Funny Fail Compilation",
    2: "Tech and Blockchain",
    3: "ASMR Cooking and Sounds",
    4: "Renewable Energy",
    5: "Talent Surfing",
    6: "Smart Furniture",
    7: "Interior Design",
    8: "Real Estate Insights",
    9: "Gym and Fitness",
    10: "English Speaking Practice",
    11: "Digital Nomad Services",
    12: "Adorable Baby Photos",
    13: "Market Predictions",
    14: "Mountain Cycling Stunts",
    15: "Career Success Strategies",
    16: "Fruit Cutting Tips",
    17: "Budget Travel Guides",
    18: "Blender Animation",
    19: "Fishing Techniques",
    20: "Athletic Moments",
    21: "World Conservation",
    22: "Ethical Hacking",
    23: "DIY Candle Making",
    24: "Adventure Activities",
    25: "Gardening Tips",
    26: "Smart Home Gadgets",
    27: "Onion Pakoda Recipe",
    28: "Fat Reduction Exercises",
    29: "Effective Fishing",
    30: "Home Science Experiments",
    31: "Woolen Flower Design",
    32: "Stock Market Trends",
    33: "Balloon Decoration Ideas",
    34: "Naruto Anime Clash",
    35: "Beginner Programming",
    36: "TikTok Challenges",
    37: "Hindi Film Summaries",
    38: "Simple Hairstyles",
    39: "Social Media Marketing",
    40: "Hit Music and Relaxation",
    41: "Programming Tutorials",
    42: "Podcast Interviews",
    43: "Taekwondo Kick Tutorial",
    44: "National Day Celebrations",
    45: "DIY Wall Decor",
    46: "Awareness Campaigns",
    47: "Jewelry Making",
    48: "Gardening Tips",
    49: "Photo Editing Tips",
    50: "Reel Tweets",
    51: "Animation Effects",
    52: "TV Watch",
    53: "Robotic Links",
    54: "Farm Tractor",
    55: "Welding Skills",
    56: "Fashion Haul",
    57: "Urdu Calligraphy",
    58: "Bike Sports",
    59: "Quran Translation",
    60: "Electric Vehicles",
    61: "Motivation Views",
    62: "Music Beats",
    63: "Funny Pranks",
    64: "Mobile Gaming",
    65: "Creative Ideas",
    66: "Free Fire",
    67: "Khan Trailer",
    68: "Graphic Design",
    69: "Sofa Bed",
    70: "Comedy Standup",
    71: "Hair Style",
    72: "Easy Drawing",
    73: "Bird Sounds",
    74: "Chess Tricks",
    75: "Price Patterns",
    76: "Software Engineer",
    77: "TikTok Trends",
    78: "Piano Music",
    79: "Financial Advice",
    80: "WhatsApp Status",
    81: "Urdu Shayari",
    82: "Physics Class",
    83: "Android Games",
    84: "Piano Tutorial",
    85: "Paint Techniques",
    86: "Web Animation",
    87: "Coding Boost",
    88: "Flower Arrangement",
    89: "Crypto News",
    90: "School Time",
    91: "Health Wellness",
    92: "Easy Crafts",
    93: "Numerology Insights",
    94: "Learning Machines",
    95: "Peppa Pig",
    96: "Recycle Bottle",
    97: "Event Planning",
    98: "Cheese Pizza",
    99: "Programming Basics",
    100: 'Trading Strategy',
    101: 'Indian Drive',
    102: 'Egg Challenge',
    103: 'Review Opinion',
    104: 'Gaming Highlight',
    105: 'Diwali Dress',
    106: 'DJ Setup',
    107: 'Engine Start',
    108: 'Makeup Look',
    109: 'Study Motivation',
    110: 'Movie Explain',
    111: 'Embroidery Stitch',
    112: 'Sport Bike',
    113: 'TikTok Compilation',
    114: 'Puppy Training',
    115: 'Ariana Vocal',
    116: 'Design Mehndi',
    117: 'Tattoo Design',
    118: 'Funny Meme',
    119: 'Chess Puzzle',
    120: 'Samsung Galaxy',
    121: 'Book Recommendation',
    122: 'Hindi Movie',
    123: 'Pose Stylish',
    124: 'Mobile Trick',
    125: 'Paneer Recipe',
    126: 'Hacker Attitude',
    127: 'Truck Driver',
    128: 'Jupiter Moon',
    129: 'Craft Idea',
    130: 'Attitude Status',
    131: 'Motivational Speech',
    132: 'Tamil Voice',
    133: 'Movie Recap',
    134: 'Luxury Dubai',
    135: 'Fashion Style',
    136: 'India Sportbike',
    137: 'Dance Performance',
    138: 'Roblox Friend',
    139: 'Thriller Series',
    140: 'Writing Class',
    141: 'Content Tool',
    142: 'Market Prediction',
    143: 'Bow Archery',
    144: 'Love Letter',
    145: 'Engagement Ring',
    146: 'Note Death',
    147: 'Live Today',
    148: 'Piano Sheet',
    149: 'Moon View',
    150: 'Psychology Insight',
    151: 'Reddit Reaction',
    152: 'Online Income',
    153: 'Drone Camera',
    154: 'Water Conservation',
    155: 'Workout Routine',
    156: 'Apple Device',
    157: 'UI/UX Design',
    158: 'Horror Story',
    159: 'Piano Believer',
    160: 'Free Fire Event',
    161: 'Coffee Brewing',
    162: 'Web Development',
    163: 'Virtual Reality',
    164: 'Tree Grafting',
    165: 'Artistic Expression',
    166: 'Cartoon Fun',
    167: 'Weight Loss Plan',
    168: 'Stock Market Analysis',
    169: 'Sad Reality',
    170: 'Solar Power',
    171: 'Medical Motivation',
    172: 'Cybersecurity Career',
    173: 'Primate Adventure',
    174: 'Nikon Photography',
    175: 'Sewing Project',
    176: 'SEO Strategy',
    177: 'Versus Comparison',
    178: 'Mobile Photography',
    179: 'Skincare Effect',
    180: 'Python Basics',
    181: 'Dog Training',
    182: 'Glass Blowing',
    183: 'Pet Care Simulator',
    184: 'Ludo Challenge',
    185: 'Fortnite Update',
    186: 'FNAF Adventure',
    187: 'Superhero Gadgets',
    188: 'Cursive Writing',
    189: 'Thai Journey',
    190: 'Respect Moment',
    191: 'Fashion Pose',
    192: 'Digital Marketing',
    193: 'Indoor Gardening',
    194: 'Climate Change',
    195: 'True Storytelling',
    196: 'Rap Instrumental',
    197: 'VR Funny Moment',
    198: 'RC Car Stunt',
    199: 'Saree Shopping',
    200: 'Gorilla Tag Update',
    201: 'Toyota Land Review',
    202: 'Kitchen Gadget',
    203: 'Funny Moments',
    204: 'Fragrance Gift',
    205: 'Luxury Resort',
    206: 'Samsung Drama',
    207: 'Fast Weight Loss',
    208: 'Big Wave Surfing',
    209: 'Morning Meditation',
    210: 'Funny Fitness',
    211: 'Animal Rescue',
    212: 'Science Fiction',
    213: 'Small Business',
    214: 'AI Future',
    215: 'Chennai Street',
    216: 'Forensic Analysis',
    217: 'Fortnite Settings',
    218: 'Copyright Disclaimer',
    219: 'Subway Slam',
    220: 'Logo Design',
    221: 'Urdu Poetry',
    222: 'Team Building',
    223: 'Designer Blouse',
    224: 'Hollywood Movie',
    225: 'Hit Songs',
    226: 'Custom Sneaker',
    227: 'Nature Sounds',
    228: 'Photoshop Tutorial',
    229: 'Hiking Adventure',
    230: 'Famous Kolkata',
    231: 'Smoke Bomb',
    232: 'DC Motor',
    233: 'Skincare Tips',
    234: 'Google Maps',
    235: 'Satisfying Art',
    236: 'Daily Vlog',
    237: 'General Knowledge',
    238: 'Street Food',
    239: 'CapCut Edit',
    240: 'Space Exploration',
    241: 'Amazing Facts',
    242: 'GTA Gamerz',
    243: 'Football Freestyle',
    244: 'Wildlife Conservation',
    245: 'Cricket Swing',
    246: 'Tanhai Dance',
    247: 'Horse Racing',
    248: 'Marvel Superheroes',
    249: 'iPhone Pro',
    250: 'Chess Masters',
    251: 'Weird History',
    252: 'Pottery Art',
    253: 'Pokemon League',
    254: 'FPV Drone Race',
    255: 'Quantum Computing',
    256: 'WhatsApp Status',
    257: 'Gacha Life',
    258: 'Earn Money',
    259: '3D Printing',
    260: 'Wedding Film',
    261: 'Football Stars',
    262: 'Skateboarding Tricks',
    263: 'Piano Tutorial',
    264: 'Telugu Cinema',
    265: 'Origami Craft',
    266: 'IIT vs JEE',
    267: 'Cake Decoration',
    268: 'Healthy Recipe',
    269: 'Yoga Flow',
    270: 'LEGO Set',
    271: 'Content Indicator',
    272: 'Minecraft Roleplay',
    273: 'Snake Ladder',
    274: 'Magic Band',
    275: 'Nail Art',
    276: 'RC Toy',
    277: 'Miniature Photography',
    278: 'Science Project',
    279: 'Magic Trick',
    280: 'Smartphone Test',
    281: 'Creative Knot',
    282: 'Family Feud',
    283: 'UPSC Interview',
    284: 'XXXTentacion Music',
    285: 'Joe Rogan Podcast',
    286: 'Aquarium Fish',
    287: 'Shiv Sneaker',
    288: 'Personal Branding',
    289: 'PBS Documentary',
    290: 'Skincare Routine',
    291: 'Motivational Quote',
    292: 'Hanuman Chalisa',
    293: 'Home Decor',
    294: 'Earn Money App',
    295: 'Hand Embroidery',
    296: 'Yin Studio Beat',
    297: 'Fox News Update',
    298: 'Beautiful Place',
    299: 'Zodiac Sign'
}

# %%
def add_descriptions_to_topics(file_path, descriptions):
    """
    Add topic descriptions to each topic in the topics.json file.

    :param file_path: Path to the topics.json file.
    :param descriptions: Dictionary with topic_id as keys and descriptions as values.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        topics_data = json.load(file)

    for topic in topics_data:
        topic_id = topic['topic_number']
        if topic_id in descriptions:
            topic['description'] = descriptions[topic_id]

    # Write the updated topics data back to the file
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(topics_data, file, ensure_ascii=False, indent=4)

# Example usage
add_descriptions_to_topics(file_path, topic_descriptions)

# %%
from elasticsearch import Elasticsearch, exceptions
import json

def upload_topics_to_elasticsearch(file_path, index_name='topics'):
    """
    Clears the existing 'topics' index and uploads topic number and description data to Elasticsearch.

    :param file_path: Path to the updated topics.json file.
    :param index_name: Name of the Elasticsearch index.
    """
    # Define database URL and credentials
    url = "http://localhost:9200/"
    username = "elastic"
    password = "gamUBg0KZZ0w5i6tikd0"

    # Setup the connection to Elasticsearch
    es = Elasticsearch(
        url,
        basic_auth=(username, password)
    )
    
    # Clear existing data in the index
    es.delete_by_query(index=index_name, body={"query": {"match_all": {}}})
    print("Cleared existing topics in Elasticsearch index.")
    
    with open(file_path, 'r', encoding='utf-8') as file:
        topics_data = json.load(file)

    for topic in topics_data:
        # Prepare document with only topic_number and description
        document = {
            'topic_number': topic['topic_number'],
            'description': topic['description']
        }

        try:
            response = es.index(index=index_name, id=topic['topic_number'], document=document)
            print(f"Uploaded topic {topic['topic_number']} to Elasticsearch: {response['_id']}")
        except exceptions.RequestError as e:
            print(f"Failed to upload topic {topic['topic_number']}. Error: {e}")
            print("Problematic topic data:", topic)
            break  # Remove break if you want to continue attempting to upload other topics


# Example usage
upload_topics_to_elasticsearch(file_path)
# Out:
# Cleared existing topics in Elasticsearch index.
# Uploaded topic 83 to Elasticsearch: 83
# Uploaded topic 213 to Elasticsearch: 213
# Uploaded topic 238 to Elasticsearch: 238
# Uploaded topic 218 to Elasticsearch: 218
# Uploaded topic 40 to Elasticsearch: 40
# Uploaded topic 11 to Elasticsearch: 11
# Uploaded topic 133 to Elasticsearch: 133
# Uploaded topic 91 to Elasticsearch: 91
# Uploaded topic 225 to Elasticsearch: 225
# Uploaded topic 17 to Elasticsearch: 17
# Uploaded topic 77 to Elasticsearch: 77
# Uploaded topic 129 to Elasticsearch: 129
# Uploaded topic 51 to Elasticsearch: 51
# Uploaded topic 223 to Elasticsearch: 223
# Uploaded topic 297 to Elasticsearch: 297
# Uploaded topic 241 to Elasticsearch: 241
# Uploaded topic 39 to Elasticsearch: 39
# Uploaded topic 165 to Elasticsearch: 165
# Uploaded topic 203 to Elasticsearch: 203
# Uploaded topic 141 to Elasticsearch: 141
# Uploaded topic 70 to Elasticsearch: 70
# Uploaded topic 119 to Elasticsearch: 119
# Uploaded topic 45 to Elasticsearch: 45
# Uploaded topic 258 to Elasticsearch: 258
# Uploaded topic 89 to Elasticsearch: 89
# Uploaded topic 121 to Elasticsearch: 121
# Uploaded topic 94 to Elasticsearch: 94
# Uploaded topic 298 to Elasticsearch: 298
# Uploaded topic 214 to Elasticsearch: 214
# Uploaded topic 210 to Elasticsearch: 210
# Uploaded topic 236 to Elasticsearch: 236
# Uploaded topic 268 to Elasticsearch: 268
# Uploaded topic 37 to Elasticsearch: 37
# Uploaded topic 240 to Elasticsearch: 240
# Uploaded topic 26 to Elasticsearch: 26
# Uploaded topic 227 to Elasticsearch: 227
# Uploaded topic 155 to Elasticsearch: 155
# Uploaded topic 251 to Elasticsearch: 251
# Uploaded topic 216 to Elasticsearch: 216
# Uploaded topic 295 to Elasticsearch: 295
# Uploaded topic 112 to Elasticsearch: 112
# Uploaded topic 42 to Elasticsearch: 42
# Uploaded topic 137 to Elasticsearch: 137
# Uploaded topic 9 to Elasticsearch: 9
# Uploaded topic 21 to Elasticsearch: 21
# Uploaded topic 104 to Elasticsearch: 104
# Uploaded topic 194 to Elasticsearch: 194
# Uploaded topic 158 to Elasticsearch: 158
# Uploaded topic 147 to Elasticsearch: 147
# Uploaded topic 79 to Elasticsearch: 79
# Uploaded topic 85 to Elasticsearch: 85
# Uploaded topic 3 to Elasticsearch: 3
# Uploaded topic 87 to Elasticsearch: 87
# Uploaded topic 0 to Elasticsearch: 0
# Uploaded topic 208 to Elasticsearch: 208
# Uploaded topic 114 to Elasticsearch: 114
# Uploaded topic 22 to Elasticsearch: 22
# Uploaded topic 118 to Elasticsearch: 118
# Uploaded topic 269 to Elasticsearch: 269
# Uploaded topic 135 to Elasticsearch: 135
# Uploaded topic 244 to Elasticsearch: 244
# Uploaded topic 172 to Elasticsearch: 172
# Uploaded topic 209 to Elasticsearch: 209
# Uploaded topic 212 to Elasticsearch: 212
# Uploaded topic 265 to Elasticsearch: 265
# Uploaded topic 282 to Elasticsearch: 282
# Uploaded topic 221 to Elasticsearch: 221
# Uploaded topic 181 to Elasticsearch: 181
# Uploaded topic 63 to Elasticsearch: 63
# Uploaded topic 23 to Elasticsearch: 23
# Uploaded topic 163 to Elasticsearch: 163
# Uploaded topic 259 to Elasticsearch: 259
# Uploaded topic 153 to Elasticsearch: 153
# Uploaded topic 24 to Elasticsearch: 24
# Uploaded topic 47 to Elasticsearch: 47
# Uploaded topic 288 to Elasticsearch: 288
# Uploaded topic 182 to Elasticsearch: 182
# Uploaded topic 257 to Elasticsearch: 257
# Uploaded topic 192 to Elasticsearch: 192
# Uploaded topic 183 to Elasticsearch: 183
# Uploaded topic 286 to Elasticsearch: 286
# Uploaded topic 272 to Elasticsearch: 272
# Uploaded topic 97 to Elasticsearch: 97
# Uploaded topic 4 to Elasticsearch: 4
# Uploaded topic 291 to Elasticsearch: 291
# Uploaded topic 202 to Elasticsearch: 202
# Uploaded topic 243 to Elasticsearch: 243
# Uploaded topic 72 to Elasticsearch: 72
# Uploaded topic 82 to Elasticsearch: 82
# Uploaded topic 279 to Elasticsearch: 279
# Uploaded topic 73 to Elasticsearch: 73
# Uploaded topic 2 to Elasticsearch: 2
# Uploaded topic 285 to Elasticsearch: 285
# Uploaded topic 262 to Elasticsearch: 262
# Uploaded topic 176 to Elasticsearch: 176
# Uploaded topic 253 to Elasticsearch: 253
# Uploaded topic 55 to Elasticsearch: 55
# Uploaded topic 60 to Elasticsearch: 60
# Uploaded topic 15 to Elasticsearch: 15
# Uploaded topic 290 to Elasticsearch: 290
# Uploaded topic 58 to Elasticsearch: 58
# Uploaded topic 134 to Elasticsearch: 134
# Uploaded topic 138 to Elasticsearch: 138
# Uploaded topic 154 to Elasticsearch: 154
# Uploaded topic 151 to Elasticsearch: 151
# Uploaded topic 230 to Elasticsearch: 230
# Uploaded topic 108 to Elasticsearch: 108
# Uploaded topic 254 to Elasticsearch: 254
# Uploaded topic 287 to Elasticsearch: 287
# Uploaded topic 157 to Elasticsearch: 157
# Uploaded topic 277 to Elasticsearch: 277
# Uploaded topic 195 to Elasticsearch: 195
# Uploaded topic 84 to Elasticsearch: 84
# Uploaded topic 211 to Elasticsearch: 211
# Uploaded topic 8 to Elasticsearch: 8
# Uploaded topic 30 to Elasticsearch: 30
# Uploaded topic 235 to Elasticsearch: 235
# Uploaded topic 38 to Elasticsearch: 38
# Uploaded topic 252 to Elasticsearch: 252
# Uploaded topic 131 to Elasticsearch: 131
# Uploaded topic 48 to Elasticsearch: 48
# Uploaded topic 161 to Elasticsearch: 161
# Uploaded topic 160 to Elasticsearch: 160
# Uploaded topic 289 to Elasticsearch: 289
# Uploaded topic 293 to Elasticsearch: 293
# Uploaded topic 103 to Elasticsearch: 103
# Uploaded topic 143 to Elasticsearch: 143
# Uploaded topic 53 to Elasticsearch: 53
# Uploaded topic 12 to Elasticsearch: 12
# Uploaded topic 204 to Elasticsearch: 204
# Uploaded topic 275 to Elasticsearch: 275
# Uploaded topic 229 to Elasticsearch: 229
# Uploaded topic 255 to Elasticsearch: 255
# Uploaded topic 177 to Elasticsearch: 177
# Uploaded topic 267 to Elasticsearch: 267
# Uploaded topic 99 to Elasticsearch: 99
# Uploaded topic 57 to Elasticsearch: 57
# Uploaded topic 152 to Elasticsearch: 152
# Uploaded topic 197 to Elasticsearch: 197
# Uploaded topic 25 to Elasticsearch: 25
# Uploaded topic 219 to Elasticsearch: 219
# Uploaded topic 98 to Elasticsearch: 98
# Uploaded topic 233 to Elasticsearch: 233
# Uploaded topic 198 to Elasticsearch: 198
# Uploaded topic 270 to Elasticsearch: 270
# Uploaded topic 10 to Elasticsearch: 10
# Uploaded topic 20 to Elasticsearch: 20
# Uploaded topic 61 to Elasticsearch: 61
# Uploaded topic 168 to Elasticsearch: 168
# Uploaded topic 276 to Elasticsearch: 276
# Uploaded topic 139 to Elasticsearch: 139
# Uploaded topic 239 to Elasticsearch: 239
# Uploaded topic 162 to Elasticsearch: 162
# Uploaded topic 156 to Elasticsearch: 156
# Uploaded topic 43 to Elasticsearch: 43
# Uploaded topic 86 to Elasticsearch: 86
# Uploaded topic 274 to Elasticsearch: 274
# Uploaded topic 71 to Elasticsearch: 71
# Uploaded topic 178 to Elasticsearch: 178
# Uploaded topic 41 to Elasticsearch: 41
# Uploaded topic 220 to Elasticsearch: 220
# Uploaded topic 80 to Elasticsearch: 80
# Uploaded topic 299 to Elasticsearch: 299
# Uploaded topic 124 to Elasticsearch: 124
# Uploaded topic 16 to Elasticsearch: 16
# Uploaded topic 231 to Elasticsearch: 231
# Uploaded topic 249 to Elasticsearch: 249
# Uploaded topic 49 to Elasticsearch: 49
# Uploaded topic 271 to Elasticsearch: 271
# Uploaded topic 52 to Elasticsearch: 52
# Uploaded topic 88 to Elasticsearch: 88
# Uploaded topic 113 to Elasticsearch: 113
# Uploaded topic 247 to Elasticsearch: 247
# Uploaded topic 283 to Elasticsearch: 283
# Uploaded topic 260 to Elasticsearch: 260
# Uploaded topic 166 to Elasticsearch: 166
# Uploaded topic 29 to Elasticsearch: 29
# Uploaded topic 179 to Elasticsearch: 179
# Uploaded topic 136 to Elasticsearch: 136
# Uploaded topic 90 to Elasticsearch: 90
# Uploaded topic 6 to Elasticsearch: 6
# Uploaded topic 193 to Elasticsearch: 193
# Uploaded topic 65 to Elasticsearch: 65
# Uploaded topic 245 to Elasticsearch: 245
# Uploaded topic 69 to Elasticsearch: 69
# Uploaded topic 36 to Elasticsearch: 36
# Uploaded topic 242 to Elasticsearch: 242
# Uploaded topic 207 to Elasticsearch: 207
# Uploaded topic 200 to Elasticsearch: 200
# Uploaded topic 96 to Elasticsearch: 96
# Uploaded topic 167 to Elasticsearch: 167
# Uploaded topic 184 to Elasticsearch: 184
# Uploaded topic 32 to Elasticsearch: 32
# Uploaded topic 56 to Elasticsearch: 56
# Uploaded topic 5 to Elasticsearch: 5
# Uploaded topic 107 to Elasticsearch: 107
# Uploaded topic 191 to Elasticsearch: 191
# Uploaded topic 116 to Elasticsearch: 116
# Uploaded topic 144 to Elasticsearch: 144
# Uploaded topic 102 to Elasticsearch: 102
# Uploaded topic 74 to Elasticsearch: 74
# Uploaded topic 256 to Elasticsearch: 256
# Uploaded topic 187 to Elasticsearch: 187
# Uploaded topic 185 to Elasticsearch: 185
# Uploaded topic 50 to Elasticsearch: 50
# Uploaded topic 109 to Elasticsearch: 109
# Uploaded topic 280 to Elasticsearch: 280
# Uploaded topic 150 to Elasticsearch: 150
# Uploaded topic 93 to Elasticsearch: 93
# Uploaded topic 175 to Elasticsearch: 175
# Uploaded topic 206 to Elasticsearch: 206
# Uploaded topic 18 to Elasticsearch: 18
# Uploaded topic 145 to Elasticsearch: 145
# Uploaded topic 35 to Elasticsearch: 35
# Uploaded topic 246 to Elasticsearch: 246
# Uploaded topic 110 to Elasticsearch: 110
# Uploaded topic 62 to Elasticsearch: 62
# Uploaded topic 140 to Elasticsearch: 140
# Uploaded topic 189 to Elasticsearch: 189
# Uploaded topic 170 to Elasticsearch: 170
# Uploaded topic 106 to Elasticsearch: 106
# Uploaded topic 68 to Elasticsearch: 68
# Uploaded topic 126 to Elasticsearch: 126
# Uploaded topic 190 to Elasticsearch: 190
# Uploaded topic 7 to Elasticsearch: 7
# Uploaded topic 28 to Elasticsearch: 28
# Uploaded topic 132 to Elasticsearch: 132
# Uploaded topic 228 to Elasticsearch: 228
# Uploaded topic 173 to Elasticsearch: 173
# Uploaded topic 224 to Elasticsearch: 224
# Uploaded topic 19 to Elasticsearch: 19
# Uploaded topic 1 to Elasticsearch: 1
# Uploaded topic 248 to Elasticsearch: 248
# Uploaded topic 100 to Elasticsearch: 100
# Uploaded topic 111 to Elasticsearch: 111
# Uploaded topic 284 to Elasticsearch: 284
# Uploaded topic 180 to Elasticsearch: 180
# Uploaded topic 174 to Elasticsearch: 174
# Uploaded topic 75 to Elasticsearch: 75
# Uploaded topic 92 to Elasticsearch: 92
# Uploaded topic 294 to Elasticsearch: 294
# Uploaded topic 164 to Elasticsearch: 164
# Uploaded topic 234 to Elasticsearch: 234
# Uploaded topic 237 to Elasticsearch: 237
# Uploaded topic 34 to Elasticsearch: 34
# Uploaded topic 273 to Elasticsearch: 273
# Uploaded topic 59 to Elasticsearch: 59
# Uploaded topic 27 to Elasticsearch: 27
# Uploaded topic 101 to Elasticsearch: 101
# Uploaded topic 222 to Elasticsearch: 222
# Uploaded topic 281 to Elasticsearch: 281
# Uploaded topic 199 to Elasticsearch: 199
# Uploaded topic 264 to Elasticsearch: 264
# Uploaded topic 171 to Elasticsearch: 171
# Uploaded topic 120 to Elasticsearch: 120
# Uploaded topic 266 to Elasticsearch: 266
# Uploaded topic 78 to Elasticsearch: 78
# Uploaded topic 250 to Elasticsearch: 250
# Uploaded topic 76 to Elasticsearch: 76
# Uploaded topic 44 to Elasticsearch: 44
# Uploaded topic 217 to Elasticsearch: 217
# Uploaded topic 127 to Elasticsearch: 127
# Uploaded topic 149 to Elasticsearch: 149
# Uploaded topic 292 to Elasticsearch: 292
# Uploaded topic 14 to Elasticsearch: 14
# Uploaded topic 13 to Elasticsearch: 13
# Uploaded topic 146 to Elasticsearch: 146
# Uploaded topic 188 to Elasticsearch: 188
# Uploaded topic 67 to Elasticsearch: 67
# Uploaded topic 278 to Elasticsearch: 278
# Uploaded topic 232 to Elasticsearch: 232
# Uploaded topic 105 to Elasticsearch: 105
# Uploaded topic 261 to Elasticsearch: 261
# Uploaded topic 64 to Elasticsearch: 64
# Uploaded topic 186 to Elasticsearch: 186
# Uploaded topic 128 to Elasticsearch: 128
# Uploaded topic 169 to Elasticsearch: 169
# Uploaded topic 201 to Elasticsearch: 201
# Uploaded topic 95 to Elasticsearch: 95
# Uploaded topic 122 to Elasticsearch: 122
# Uploaded topic 33 to Elasticsearch: 33
# Uploaded topic 46 to Elasticsearch: 46
# Uploaded topic 205 to Elasticsearch: 205
# Uploaded topic 123 to Elasticsearch: 123
# Uploaded topic 196 to Elasticsearch: 196
# Uploaded topic 130 to Elasticsearch: 130
# Uploaded topic 226 to Elasticsearch: 226
# Uploaded topic 263 to Elasticsearch: 263
# Uploaded topic 125 to Elasticsearch: 125
# Uploaded topic 148 to Elasticsearch: 148
# Uploaded topic 115 to Elasticsearch: 115
# Uploaded topic 117 to Elasticsearch: 117
# Uploaded topic 54 to Elasticsearch: 54
# Uploaded topic 66 to Elasticsearch: 66
# Uploaded topic 142 to Elasticsearch: 142
# Uploaded topic 215 to Elasticsearch: 215
# Uploaded topic 159 to Elasticsearch: 159
# Uploaded topic 81 to Elasticsearch: 81
# Uploaded topic 31 to Elasticsearch: 31
# Uploaded topic 296 to Elasticsearch: 296
